# %%
#import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#read file and print using head function the first few rows
df=pd.read_excel('ElectionData.xlsx')
df.head()
# Out:
#    TimeElapsed                time         territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 1            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 2            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 3            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 4            0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                   2.5       8874  ...                 52.66
# ...

# %%
df.shape
#shape prints the number of rows and columns; ie here there are 21643 rows and 28 columns
# Out:
# (21643, 28)

# %%
df.columns
#here are the names of the columns in the dataset
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
df.dtypes
#it tells us the datatypes of the columns in the dataset
# Out:
# TimeElapsed                          int64
# time                        datetime64[ns]
# territoryName                       object
# totalMandates                        int64
# availableMandates                    int64
# numParishes                          int64
# numParishesApproved                  int64
# blankVotes                           int64
# blankVotesPercentage               float64
# nullVotes                            int64
# nullVotesPercentage                float64
# votersPercentage                   float64
# subscribedVoters                     int64
# totalVoters                          int64
# pre.blankVotes                       int64
# pre.blankVotesPercentage           float64
# pre.nullVotes                        int64
# pre.nullVotesPercentage            float64
# pre.votersPercentage               float64
# pre.subscribedVoters                 int64
# pre.totalVoters                      int64
# Party                               object
# ...

# %%
df.info()
#info function gives a concise summary of the dataframe; it tells us the datatype  and number of non null values of each column
#here it shows that there are 1 date and time, 8 float , 17 integer and 2  object/string values columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  datetime64[ns]
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %%
df.describe()
#it tells us the statistical inference
# Out:
#         TimeElapsed  totalMandates  availableMandates   numParishes  \
# count  21643.000000   21643.000000       21643.000000  21643.000000
# mean     133.146052      11.544795          11.499284    309.956013
# std       77.651193      31.314567          31.738783    659.055911
# min        0.000000       0.000000           0.000000     54.000000
# 25%       65.000000       1.000000           0.000000     75.000000
# 50%      135.000000       4.000000           3.000000    147.000000
# 75%      200.000000       9.000000           9.000000    242.000000
# max      265.000000     226.000000         226.000000   3092.000000
#
#        numParishesApproved     blankVotes  blankVotesPercentage     nullVotes  \
# count         21643.000000   21643.000000          21643.000000  21643.000000
# mean            261.090237    8875.066673              2.621629   6148.068752
# std             583.377428   21484.874088              0.795289  14735.469269
# ...

# %% [markdown]
# Here there are 21643 entries in each columns. Hence the count shows 21643.
#
# Mean - Mean for the TimeElapsed is 133.146052 and total Mandates is 11.544795
#
# Standard Deviation , std - STD for TimeElapsed is 77.651193	 and total Mandates is 31.314567
#
# The min value in the column is denoted by min. Min value for TimeElapsed  and total Mandates are 0.
#
# The maximum value in the column is denoted by max. Max value for TimeElapsed is 265.000 and  total  Mandates is 226.00.
#
# 25%, 50%, and 75% - IQR values it shows percentile values at 25%,50% and 75% ; for TimeElapsed it is 65.000 , 135.00 and 200.00	 respectively

# %%
df.isnull().sum()
#lets check the null values; there are no null values here
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
sns.heatmap(df.isnull())
#using heatmap we can see that there are no null values

# %%
#get correlations of numerical features in dataset

corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
# Dropping columns from correlation heatmap with ultiple observations of high correlation coefficients(>0.90) to avoid multicollinearity


df.drop(['totalMandates','numParishesApproved','blankVotes','nullVotes','subscribedVoters','totalVoters','pre.blankVotes','pre.nullVotes','pre.subscribedVoters','pre.totalVoters','Percentage','Mandates','pre.blankVotesPercentage','pre.votersPercentage'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    TimeElapsed                time         territoryName  availableMandates  \
# 0            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
# 1            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
# 2            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
# 3            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
# 4            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
#
#    numParishes  blankVotesPercentage  nullVotesPercentage  votersPercentage  \
# 0         3092                   2.5                  2.3             51.36
# 1         3092                   2.5                  2.3             51.36
# 2         3092                   2.5                  2.3             51.36
# 3         3092                   2.5                  2.3             51.36
# 4         3092                   2.5                  2.3             51.36
#
# ...

# %%
df.shape
# Out:
# (21643, 14)

# %%
df['territoryName'].value_counts()
#counting the each element in the territory name
# Out:
# Leiria                  1134
# TerritÃ³rio Nacional    1134
# Porto                   1134
# Braga                   1134
# Coimbra                 1080
# Viana do Castelo        1080
# Viseu                   1080
# Aveiro                  1080
# Lisboa                  1080
# SetÃºbal                1080
# Madeira                 1080
# Ã‰vora                  1026
# SantarÃ©m               1026
# Faro                    1026
# Guarda                  1026
# BraganÃ§a                972
# Castelo Branco           972
# Portalegre               918
# Beja                     918
# Vila Real                864
# AÃ§ores                  799
# Name: territoryName, dtype: int64

# %%
df['Party'].value_counts()
#counting each element in the party column
# Out:
# PCP-PEV      1127
# PAN          1127
# A            1127
# PNR          1127
# IL           1127
# L            1127
# PDR          1127
# B.E.         1127
# PS           1127
# PPD/PSD      1127
# PCTP/MRPP    1127
# CH           1127
# CDS-PP       1127
# PPM          1073
# R.I.R.       1026
# MPT          1019
# PTP          1019
# NC            972
# PURP          972
# JPP           486
# MAS           425
# Name: Party, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TimeElapsed              21643 non-null  int64
#  1   time                     21643 non-null  datetime64[ns]
#  2   territoryName            21643 non-null  object
#  3   availableMandates        21643 non-null  int64
#  4   numParishes              21643 non-null  int64
#  5   blankVotesPercentage     21643 non-null  float64
#  6   nullVotesPercentage      21643 non-null  float64
#  7   votersPercentage         21643 non-null  float64
#  8   pre.nullVotesPercentage  21643 non-null  float64
#  9   Party                    21643 non-null  object
#  10  validVotesPercentage     21643 non-null  float64
#  11  Votes                    21643 non-null  int64
#  12  Hondt                    21643 non-null  int64
#  13  FinalMandates            21643 non-null  int64
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
# Numerical columns

numerical_variables=[features for features in df.columns if df[features].dtypes!='O']
numerical_variables.remove('FinalMandates')
numerical_variables
# Out:
# ['TimeElapsed',
#  'time',
#  'availableMandates',
#  'numParishes',
#  'blankVotesPercentage',
#  'nullVotesPercentage',
#  'votersPercentage',
#  'pre.nullVotesPercentage',
#  'validVotesPercentage',
#  'Votes',
#  'Hondt']

# %%
df['TimeElapsed'].hist()
#using histogram lets plot timeelapsed

# %%
df['availableMandates'].hist()

# %%
df['numParishes'].hist()

# %%
df['blankVotesPercentage'].hist()

# %%
df['nullVotesPercentage'].hist()

# %%
df['votersPercentage'].hist()

# %%
df['pre.nullVotesPercentage'].hist()

# %%
df['validVotesPercentage'].hist()

# %%
df['Votes'].hist()

# %%
df['Hondt'].hist()

# %% [markdown]
# Inference about distribution of variables:- Normal Distribution:-
#
# 1. blankVotesPercentage
# 2. nullVotesPercentage
# 3. pre.nullVotesPercentage
#
# Skewed Normal Distribution:-
#
# votersPercentage skewed to the right
#
#
# Exponential distribution:-
#
# 1. AvailableMandates
# 2. validVotesPercentage
# 3. Votes
# 4. Hondt
#
# Non-conclusive Distribution:-
#
# 1. TimeElapsed
# 2. NumParishes
#
# Therefore since all the variables are not normally distributed, normalization is required for regression

# %%
# Plotting PMF distribution for columns with few unique values
# plot the probability of the occurence of unique values when picked up randomly
def pmf_func(dataset,lists):
    for i in lists:
        pmf = dataset[i].value_counts().sort_index() / len(dataset[i])
        plt.figure(figsize = (20,6))
        pmf.plot(kind='bar')
        plt.xlabel(i)
        plt.ylabel('PMF')
        plt.xlim(0,100)
few_unique=['TimeElapsed','availableMandates','numParishes','pre.nullVotesPercentage','Hondt','FinalMandates']        
pmf_func(df,few_unique)

# %% [markdown]
# From the PMF plot we can get the probability of each unique value in a numerical variable and is more effective for variables with less number of unique values Inference:- The following variables have 0 as the most dominant value:-
#
# 1.Number of MP's according to the distribution of votes (Hondt)
#
# 2.MP's elected at the moment for the party in a given district (Mandates),
#
# 3.Target: final number of elected MP's in a district/national-leve
#
# 4.MP's left to elect at the moment (availableMandates)
#
# Locations with 69 parishes is the most probable among all locations.

# %% [markdown]
# ECDF plot

# %%
from scipy.stats import norm
def cdf_func(dataset,lists):
    for i in lists:
        plt.figure(figsize = (20,6))
        plt.hist(dataset[i], density=True, cumulative=True, label='CDF', alpha=0.8)
        plt.xlabel(i)
        plt.ylabel('CDF')
cdf_func(df,numerical_variables)

# %% [markdown]
# Chi Square Test for finding out if Party and territoryName are related (categorical variables)

# %%
import scipy.stats as stats

dataset_table=pd.crosstab(df['territoryName'],df['Party'])
print(dataset_table)
# Out:
# Party                  A  B.E.  CDS-PP  CH  IL  JPP   L  MAS  MPT  NC  ...  \
# territoryName                                                          ...
# Aveiro                54    54      54  54  54   54  54    0   54  54  ...
# AÃ§ores               47    47      47  47  47    0  47   47   47   0  ...
# Beja                  54    54      54  54  54    0  54    0   54  54  ...
# Braga                 54    54      54  54  54   54  54   54   54  54  ...
# BraganÃ§a             54    54      54  54  54    0  54    0    0  54  ...
# Castelo Branco        54    54      54  54  54    0  54    0   54   0  ...
# Coimbra               54    54      54  54  54   54  54   54   54  54  ...
# Faro                  54    54      54  54  54    0  54    0   54  54  ...
# Guarda                54    54      54  54  54    0  54    0   54  54  ...
# Leiria                54    54      54  54  54   54  54   54   54  54  ...
# ...

# %%
dataset_table.values
# Out:
# array([[54, 54, 54, 54, 54, 54, 54,  0, 54, 54, 54, 54, 54, 54, 54, 54,
#         54, 54, 54, 54, 54],
#        [47, 47, 47, 47, 47,  0, 47, 47, 47,  0, 47, 47, 47, 47, 47, 47,
#         47, 47, 47,  0,  0],
#        [54, 54, 54, 54, 54,  0, 54,  0, 54, 54, 54, 54, 54, 54, 54, 54,
#         54, 54, 54,  0,  0],
#        [54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54,
#         54, 54, 54, 54, 54],
#        [54, 54, 54, 54, 54,  0, 54,  0,  0, 54, 54, 54, 54, 54, 54, 54,
#         54, 54, 54, 54, 54],
#        [54, 54, 54, 54, 54,  0, 54,  0, 54,  0, 54, 54, 54, 54, 54, 54,
#         54, 54, 54, 54, 54],
#        [54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54,
#         54, 54,  0, 54, 54],
#        [54, 54, 54, 54, 54,  0, 54,  0, 54, 54, 54, 54, 54, 54, 54, 54,
#         54, 54, 54, 54, 54],
#        [54, 54, 54, 54, 54,  0, 54,  0, 54, 54, 54, 54, 54, 54, 54, 54,
#         54, 54, 54, 54, 54],
# ...

# %%
#Observed Values
Observed_Values = dataset_table.values 
print("Observed Values :-\n",Observed_Values)
# Out:
# Observed Values :-
#  [[54 54 54 54 54 54 54  0 54 54 54 54 54 54 54 54 54 54 54 54 54]
#  [47 47 47 47 47  0 47 47 47  0 47 47 47 47 47 47 47 47 47  0  0]
#  [54 54 54 54 54  0 54  0 54 54 54 54 54 54 54 54 54 54 54  0  0]
#  [54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54]
#  [54 54 54 54 54  0 54  0  0 54 54 54 54 54 54 54 54 54 54 54 54]
#  [54 54 54 54 54  0 54  0 54  0 54 54 54 54 54 54 54 54 54 54 54]
#  [54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54  0 54 54]
#  [54 54 54 54 54  0 54  0 54 54 54 54 54 54 54 54 54 54 54 54 54]
#  [54 54 54 54 54  0 54  0 54 54 54 54 54 54 54 54 54 54 54 54 54]
#  [54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54]
#  [54 54 54 54 54  0 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54]
#  [54 54 54 54 54 54 54  0 54 54 54 54 54 54 54 54 54 54 54 54 54]
#  [54 54 54 54 54  0 54  0 54  0 54 54 54 54 54 54  0 54 54 54 54]
#  [54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54 54]
# ...

# %%
val=stats.chi2_contingency(dataset_table)
val
# Out:
# (1948.5199687841082,
#  1.3607820211281645e-201,
#  400,
#  array([[56.23804463, 56.23804463, 56.23804463, 56.23804463, 56.23804463,
#          24.25172111, 56.23804463, 21.20778081, 50.84877328, 48.50344222,
#          56.23804463, 56.23804463, 56.23804463, 56.23804463, 56.23804463,
#          56.23804463, 53.54340895, 56.23804463, 50.84877328, 48.50344222,
#          51.1980779 ],
#         [41.60573858, 41.60573858, 41.60573858, 41.60573858, 41.60573858,
#          17.94178256, 41.60573858, 15.68983043, 37.61867578, 35.88356512,
#          41.60573858, 41.60573858, 41.60573858, 41.60573858, 41.60573858,
#          41.60573858, 39.61220718, 41.60573858, 37.61867578, 35.88356512,
#          37.87709652],
#         [47.80233794, 47.80233794, 47.80233794, 47.80233794, 47.80233794,
#          20.61396294, 47.80233794, 18.02661369, 43.22145728, 41.22792589,
#          47.80233794, 47.80233794, 47.80233794, 47.80233794, 47.80233794,
# ...

# %%
Expected_Values=val[3]

# %%
no_of_rows=len(dataset_table.iloc[0:2,0])

no_of_columns=len(dataset_table.iloc[0,0:2])
ddof=(no_of_rows-1)*(no_of_columns-1)
print("Degree of Freedom:-",ddof)
alpha = 0.05
# Out:
# Degree of Freedom:- 1

# %%
from scipy.stats import chi2
chi_square=sum([(o-e)**2./e for o,e in zip(Observed_Values,Expected_Values)])
chi_square_statistic=chi_square[0]+chi_square[1]

# %%
print("chi-square statistic:-",chi_square_statistic)
# Out:
# chi-square statistic:- 13.878458601485704

# %%
critical_value=chi2.ppf(q=1-alpha,df=ddof)

print('critical_value:',critical_value)
# Out:
# critical_value: 3.841458820694124

# %%
#p-value
p_value=1-chi2.cdf(x=chi_square_statistic,df=ddof)
print('p-value:',p_value)
print('Significance level: ',alpha)
print('Degree of Freedom: ',ddof)
print('p-value:',p_value)
# Out:
# p-value: 0.00019502095665746566
# Significance level:  0.05
# Degree of Freedom:  1
# p-value: 0.00019502095665746566

# %%
if chi_square_statistic>=critical_value:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
    
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Reject H0,There is a relationship between 2 categorical variables
# Reject H0,There is a relationship between 2 categorical variables

# %%
# Categorical Variables

categorcial_variables = ['territoryName','Party']

for col in categorcial_variables:
    plt.figure(figsize=(10,4))
    #plt.hist(col, normed=True, cumulative=True, label='CDF',histtype='step', alpha=0.8, color='k')
    sns.barplot(df[col].value_counts().values, df[col].value_counts().index)
    plt.title(col)
    plt.tight_layout()

# %% [markdown]
# Half the number of parties are equally dominant from the election standpoint. Porta, Braga are among the largest cities in Portugal having a large pool of voters.

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'availableMandates',
#        'numParishes', 'blankVotesPercentage', 'nullVotesPercentage',
#        'votersPercentage', 'pre.nullVotesPercentage', 'Party',
#        'validVotesPercentage', 'Votes', 'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
#Categorical variable analysis

pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index =['territoryName','availableMandates'] ,values = 'numParishes').sort_values('numParishes',ascending=False)
# Out:
#                                         numParishes
# territoryName        availableMandates
# TerritÃ³rio Nacional 25                        3092
#                      0                         3092
#                      101                       3092
#                      116                       3092
#                      130                       3092
#                      226                       3092
#                      214                       3092
#                      17                        3092
#                      139                       3092
#                      144                       3092
#                      158                       3092
#                      9                         3092
#                      162                       3092
#                      212                       3092
#                      210                       3092
#                      204                       3092
# ...

# %% [markdown]
# The National capital region has the most number of Parishes which are local administrative subdivisions similar to constituencies. The capital region also has also has the most number of parliamentary seats being contested

# %%
# Types of votes w.r.t party
pd.pivot_table(df, index ='Party' ,values = 'blankVotesPercentage').sort_values('blankVotesPercentage',ascending=False)
# Out:
#            blankVotesPercentage
# Party
# MAS                    3.033035
# JPP                    2.710329
# MPT                    2.671384
# PPM                    2.638211
# A                      2.618181
# PCP-PEV                2.618181
# PS                     2.618181
# PPD/PSD                2.618181
# PNR                    2.618181
# PDR                    2.618181
# PCTP/MRPP              2.618181
# PAN                    2.618181
# B.E.                   2.618181
# L                      2.618181
# IL                     2.618181
# CH                     2.618181
# CDS-PP                 2.618181
# PTP                    2.596045
# PURP                   2.563724
# R.I.R.                 2.544834
# NC                     2.544691

# %%
pd.pivot_table(df, index ='Party' ,values = 'nullVotesPercentage').sort_values('nullVotesPercentage',ascending=False)
# Out:
#            nullVotesPercentage
# Party
# R.I.R.                1.995624
# PURP                  1.970031
# PPM                   1.967875
# B.E.                  1.965741
# PS                    1.965741
# PPD/PSD               1.965741
# PNR                   1.965741
# PDR                   1.965741
# PCTP/MRPP             1.965741
# PCP-PEV               1.965741
# A                     1.965741
# L                     1.965741
# IL                    1.965741
# CH                    1.965741
# CDS-PP                1.965741
# PAN                   1.965741
# NC                    1.956379
# JPP                   1.949547
# PTP                   1.933759
# MPT                   1.923994
# MAS                   1.877671

# %%
pd.pivot_table(df, index ='Party' ,values = 'validVotesPercentage').sort_values('validVotesPercentage',ascending=False)
# Out:
#            validVotesPercentage
# Party
# PS                    39.513789
# PPD/PSD               30.498900
# B.E.                   8.941145
# PCP-PEV                6.982227
# CDS-PP                 4.674836
# PAN                    2.544020
# CH                     1.362236
# PCTP/MRPP              0.780195
# R.I.R.                 0.763733
# IL                     0.753744
# L                      0.753709
# JPP                    0.696811
# A                      0.669246
# PNR                    0.280027
# PURP                   0.250442
# MPT                    0.246349
# NC                     0.244516
# PTP                    0.200736
# PDR                    0.199876
# PPM                    0.190475
# MAS                    0.100541

# %% [markdown]
# From the above pivot tables we can conclude:-
#
# 1. MAS party has the most number of blank votes
# 2. RIR party has the most number of null votes
# 3. PS party has the most number of valid votes

# %%
pd.pivot_table(df,index ='Party', values = 'FinalMandates',aggfunc=np.mean).sort_values('FinalMandates', ascending = False)
# Out:
#            FinalMandates
# Party
# PS             10.139308
# PPD/PSD         7.366460
# B.E.            1.820763
# PCP-PEV         1.149956
# CDS-PP          0.479148
# PAN             0.383319
# CH              0.095830
# IL              0.095830
# L               0.095830
# PNR             0.000000
# PURP            0.000000
# PTP             0.000000
# PPM             0.000000
# A               0.000000
# PDR             0.000000
# PCTP/MRPP       0.000000
# NC              0.000000
# MPT             0.000000
# MAS             0.000000
# JPP             0.000000
# R.I.R.          0.000000

# %% [markdown]
# The 3 dominant parties by finalmandates are as follows:-
#
# 1. PS
# 2. PPD/PSD
# 3. B.E

# %%
pd.pivot_table(df,index ='territoryName', values = 'FinalMandates',aggfunc='count').sort_values('FinalMandates', ascending = False)
# Out:
#                       FinalMandates
# territoryName
# Leiria                         1134
# Braga                          1134
# TerritÃ³rio Nacional           1134
# Porto                          1134
# Aveiro                         1080
# Viseu                          1080
# Viana do Castelo               1080
# SetÃºbal                       1080
# Madeira                        1080
# Lisboa                         1080
# Coimbra                        1080
# Guarda                         1026
# Faro                           1026
# SantarÃ©m                      1026
# Ã‰vora                         1026
# Castelo Branco                  972
# BraganÃ§a                       972
# Portalegre                      918
# Beja                            918
# Vila Real                       864
# AÃ§ores                         799

# %%
df.isnull().sum()
# Out:
# TimeElapsed                0
# time                       0
# territoryName              0
# availableMandates          0
# numParishes                0
# blankVotesPercentage       0
# nullVotesPercentage        0
# votersPercentage           0
# pre.nullVotesPercentage    0
# Party                      0
# validVotesPercentage       0
# Votes                      0
# Hondt                      0
# FinalMandates              0
# dtype: int64

# %%
# Scatter Plot
def scatter_func(dataset,lists):
    for i in lists:
        plt.figure(figsize = (6,6))
        sns.scatterplot(x=dataset[i],y=dataset['FinalMandates'],data=dataset)
        plt.xlabel(i)
        plt.ylabel('FinalMandates')
scatter_func(df,numerical_variables)

# %% [markdown]
# From the scatterplots we can infer that the distribution of the independant data points w.r.t to the dependant variable is a static one, i.e, a very minute gradient/slope as a majority of points occupy the lower regions of the plot and have a constant ceiling. Although, there is a more profound linear relationship between votes,holdt with finalmandates(target variable). All distributions have significant outliers

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'availableMandates',
#        'numParishes', 'blankVotesPercentage', 'nullVotesPercentage',
#        'votersPercentage', 'pre.nullVotesPercentage', 'Party',
#        'validVotesPercentage', 'Votes', 'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
sns.pairplot(data=df)

# %% [markdown]
# From the pairplot we can oserve that Mandates, validVotesPercentafe, Votes and Hondt are linear in their distribution with the target variable FinalMandates.

# %%
# boxplot to get a better understanding of outliers
def box_func(dataset,lists):
    for i in lists:
        plt.figure(figsize = (6,6))
        dataset.boxplot(column=[i])
        plt.xlabel(i)
lis=['TimeElapsed','availableMandates','numParishes','validVotesPercentage','Votes','Hondt','blankVotesPercentage','nullVotesPercentage','votersPercentage','pre.nullVotesPercentage']
box_func(df,lis)
#df.boxplot(column = ['TimeElapsed','availableMandates','numParishes','validVotesPercentage','Votes','Hondt','blankVotesPercentage','nullVotesPercentage','votersPercentage','pre.nullVotesPercentage'])

# %% [markdown]
# Many variables in the dataset have significant outliers

# %%
df.head()
# Out:
#    TimeElapsed  availableMandates  numParishes  blankVotesPercentage  \
# 0            0                226         3092                   2.5
# 1            0                226         3092                   2.5
# 2            0                226         3092                   2.5
# 3            0                226         3092                   2.5
# 4            0                226         3092                   2.5
#
#    nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  \
# 0                  2.3             51.36                     1.91
# 1                  2.3             51.36                     1.91
# 2                  2.3             51.36                     1.91
# 3                  2.3             51.36                     1.91
# 4                  2.3             51.36                     1.91
#
#    validVotesPercentage   Votes  Hondt  FinalMandates  Dates_encoded  \
# 0                 40.22  147993     94            106              0
# ...

# %%
df=df.drop('Party_encoded',axis=1)

# %%
# Standardization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(df.drop('FinalMandates',axis=1))
scaled_features=scaler.transform(df.drop('FinalMandates',axis=1))
dataset_scaled=pd.DataFrame(scaled_features,columns=df.columns[:-1])
dataset_scaled.head()
# Out:
#    TimeElapsed  availableMandates  numParishes  blankVotesPercentage  \
# 0    -1.714708           6.758472     4.221354             -0.152941
# 1    -1.714708           6.758472     4.221354             -0.152941
# 2    -1.714708           6.758472     4.221354             -0.152941
# 3    -1.714708           6.758472     4.221354             -0.152941
# 4    -1.714708           6.758472     4.221354             -0.152941
#
#    nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  \
# 0             0.902163         -0.128489                 0.340951
# 1             0.902163         -0.128489                 0.340951
# 2             0.902163         -0.128489                 0.340951
# 3             0.902163         -0.128489                 0.340951
# 4             0.902163         -0.128489                 0.340951
#
#    validVotesPercentage     Votes      Hondt  FinalMandates  Dates_encoded  \
# ...

# %%
# Splitting dataset into train and test sets


X=df.drop(['FinalMandates'],axis=1)    #independent columns
y=df['FinalMandates']     #target column i.e price range
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# Feature Selection

# %% [markdown]
# Model Selection
# The next step is to try several models with our data (without hyperparameter tune up) to see which one yields better results. We will use cross validation 20-folds to get the score for each model (mean of all folds). The score function we are using is negative mean square errors which is the opposite of MSE as cross validation function expects a score where lower is better.
#
# Using this procedure we are going to try the following models:
#
# 1. Linear regression
#
# 2. Decision Tree
#
# 3. Random Forest

# %%
from sklearn.tree import DecisionTreeRegressor  
  
# create a regressor object 
regressor = DecisionTreeRegressor(random_state = 0)  
  
# fit the regressor with X and Y data 
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
from sklearn.model_selection import cross_val_score
tree_scores = cross_val_score(regressor, X_train, y_train, scoring="neg_mean_squared_error", cv=20)
tree_rmse_scores = np.sqrt(-tree_scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Scores: [0.25938836 0.05448245 0.05136655 0.08121765 0.05136655 0.07264327
#  0.03632164 0.05136655 0.08121765 0.03632164 0.03634562 0.27917599
#  0.05140047 0.06295246 0.08902822 0.25700233 0.08127127 0.06295246
#  0.10280093 0.11636275]
# Mean: 0.0957492399236782
# Standard deviation: 0.07430810890027839

# %%
from sklearn.linear_model import LinearRegression
print("Model: Linear Regression")
lin_reg = LinearRegression()

tree_scores = cross_val_score(lin_reg, X_train, y_train, scoring="neg_mean_squared_error", cv=20)
tree_rmse_scores = np.sqrt(-tree_scores)

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Model: Linear Regression
# Scores: [0.69701011 0.67831082 0.69439736 0.44741073 0.66617663 0.6228765
#  0.65554936 0.64022988 0.62241691 0.59499554 0.53810889 0.71031406
#  0.61888099 0.73236124 0.62468441 0.52648765 0.6857807  0.61012915
#  0.47867093 0.75801063]
# Mean: 0.6301401257875807
# Standard deviation: 0.07960586534975758

# %%
from sklearn.ensemble import RandomForestRegressor
print("Model: Random Forest Regressor")
forest_reg = RandomForestRegressor()

tree_scores = cross_val_score(forest_reg, X_train, y_train, scoring="neg_mean_squared_error", cv=20)
tree_rmse_scores = np.sqrt(-tree_scores)

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Model: Random Forest Regressor
# Scores: [0.14499023 0.06513229 0.04658807 0.10680908 0.09808658 0.06849681
#  0.03227929 0.05266762 0.08354415 0.03474896 0.05295994 0.22680749
#  0.04493468 0.13585728 0.07682435 0.06667811 0.04575061 0.03344192
#  0.07254935 0.09125458]
# Mean: 0.07902007102178381
# Standard deviation: 0.045906575858769644

# %%
#Feature importance is an inbuilt class that comes with Tree Based Classifiers. Its been used here to extract 10 top features
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
# Out:
# [0.00485155 0.02756765 0.04119983 0.02331767 0.0178263  0.02373164
#  0.02188622 0.31020966 0.14588929 0.32693932 0.00061293 0.00286417
#  0.03482993 0.01827384]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# From the output we can infer : 1) Percentage of valid votes in a party plays a crucial role in determining the final mandates accounting for 29% of the splits. 2) Another important feature is the Number of MP's according to the present distribution of votes. 3) Percentage of party votes is also present on many splits. 4) MP's elected at the moment for the party in a given district is essential for the determination of final mandates 5) Total number of parishes in this location affects the final mandates.

# %%
#get correlations of each feature in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# The best model (using sklearn default values for model parameters) is Random Forest. This model yields the best RMSE (0.08315) and the smallest standard deviation (0.0451) which means it is more robust than the other models. We will now tune up the hyperparameters of the selected model.

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [{'n_estimators': [50,100,200], 'max_features': [5,10,15,18],
               'bootstrap': [True,False], 'min_samples_leaf':[1,2], 
               'min_samples_split':[2,3]}]

forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error',verbose=1)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 480 out of 480 | elapsed: 31.8min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
# ...

# %%
print(" ----------------- GRID_SEARCH INFO -----------------\n ")

print(grid_search.best_params_)
print(grid_search.best_estimator_)
print("Best CV score:", np.sqrt(-grid_search.best_score_))

cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
#  ----------------- GRID_SEARCH INFO -----------------
#
# {'bootstrap': False, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
# RandomForestRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features=10, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=3, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# Best CV score: 0.07858179033514844
# 0.12793915807388132 {'bootstrap': True, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.14058901149810887 {'bootstrap': True, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# ...

# %%
from sklearn.metrics import mean_squared_error


final_model = grid_search.best_estimator_
# predictions
final_predictions = final_model.predict(X_test)
# calculate RMSE
final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 0.08988131109806206

# %%
# Computing R^2 performance metric for the regression model
from sklearn import metrics
print('R2_Score: ', metrics.r2_score(y_test,final_predictions))
# Out:
# R2_Score:  0.9998562245050804

# %%
plt.figure(figsize=(6,6))

plt.scatter(y_test,final_predictions,alpha=1, s=1)
plt.xlabel('observed', fontsize=12)
plt.ylabel('predictions', fontsize=12)
plt.plot([0,(np.max(y_test) + 5000)],[0,(np.max(y_test) + 5000)], 'r--', alpha=0.5)
plt.axis([0,20,0,20])
plt.show()

# %%
#save the model

from sklearn.externals import joblib

joblib.dump(forest_reg,'Model_Portugal Elections.pkl')
# Out:
# ['Model_Portugal Elections.pkl']
