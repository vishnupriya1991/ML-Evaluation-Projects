# %%
#import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#read dataset
df=pd.read_csv('temp.csv')
df.head()
#print using head function; head function prints first few rows of the dataset
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0  2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0  2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0  2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0  2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.shape
#lets see the number of rows and columns; here there are 7752 rows and 25 columns
# Out:
# (7752, 25)

# %%
df.dtypes
#lets check the data type of each column
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
df.columns
#it shows the names of the columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.info()
#info function gives a concise summary of the dataframe;it shows us the data types of the columns and non null value counts
#here it shows that there are 24 float and 1 object valued column in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
df.describe()
#describe function tells us the statistical inference about the dataset
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %%
#From the above statistical table we can understand: We can see that for each column we have the following functions

count- Number of non-null observations here all the columns contain 7750 entries 

mean- Mean of Values here mean of each column is found ie, mean of station column= 13 , Present_Tmax is 29.768211 etc

std- Standard Deviation of the Values here standard deviation for station is 7.211568 , Present_Tmax is 2.969999 etc

min- Minimum value here it shows the min value for station is 1 , Present_Tmax is 20 etc

max- Maximum value it shows the max value for station is 25 , Present_Tmax is 37.60000 .

25%, 50%, and 75% - IQR values it shows percentile values at 25%,50% and 75% ; for station is 7 , 13 , 19 respectively.

# %%
df.isnull().sum()
#lets check the null values
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
sns.heatmap(df.isnull())
#using heatmap lets see the null values; its clear that there are lots of null values in the given dataset

# %%
#lets fill the null values using for loop
for col in ['station','Present_Tmax','Date','Present_Tmin','LDAPS_RHmin','LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_Tmin_lapse','LDAPS_WS','LDAPS_LH','LDAPS_CC1','LDAPS_CC2','LDAPS_CC3','LDAPS_CC4','LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4','lat','lon','DEM','Slope','Solar radiation','Next_Tmax','Next_Tmin']:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.isnull().sum()
#now lets check the null values ; now there are no null values
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
sns.distplot(df['Next_Tmax'])
#lets plot Next_Tmax using heatmap

# %%
sns.distplot(df['Next_Tmin'])

# %%
sns.distplot(df['Present_Tmax'])

# %%
sns.distplot(df['Present_Tmin'])

# %%
sns.distplot(df['LDAPS_RHmin'])

# %%
sns.distplot(df['LDAPS_RHmax'])

# %%
sns.distplot(df['LDAPS_Tmax_lapse'])

# %%
sns.distplot(df['LDAPS_Tmin_lapse'])

# %%
sns.distplot(df['LDAPS_WS'])

# %%
df['Date'].value_counts()
#lets count the date
# Out:
# 2013-06-30    27
# 2015-07-15    25
# 2014-08-05    25
# 2017-07-25    25
# 2013-08-12    25
#               ..
# 2014-07-29    25
# 2017-08-13    25
# 2014-07-13    25
# 2017-08-22    25
# 2013-07-10    25
# Name: Date, Length: 310, dtype: int64

# %%
df['Day']=df['Date'].str.split('-').str[0].astype(int)
df['Month']=df['Date'].str.split('-').str[1].astype(int)

# %%
df['Date']
# Out:
# 0       2013-06-30
# 1       2013-06-30
# 2       2013-06-30
# 3       2013-06-30
# 4       2013-06-30
#            ...
# 7747    2017-08-30
# 7748    2017-08-30
# 7749    2017-08-30
# 7750    2013-06-30
# 7751    2013-06-30
# Name: Date, Length: 7752, dtype: object

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0  2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0  2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0  2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0  2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT4  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.drop(['Date'],axis=1,inplace=True)
#dropping the irrelevant column date as we have converted it to int.

# %%
df.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#    LDAPS_PPT4      lat      lon       DEM   Slope  Solar radiation  Next_Tmax  \
# ...

# %%
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Day                 0
# Month               0
# dtype: int64

# %%
df.skew()
#lets check the skweness
# Out:
# station             0.000100
# Present_Tmax       -0.276483
# Present_Tmin       -0.375457
# LDAPS_RHmin         0.202176
# LDAPS_RHmax        -1.109283
# LDAPS_Tmax_lapse   -0.601161
# LDAPS_Tmin_lapse   -0.851245
# LDAPS_WS            1.485885
# LDAPS_LH            0.586176
# LDAPS_CC1           0.460727
# LDAPS_CC2           0.474379
# LDAPS_CC3           0.643064
# LDAPS_CC4           0.671739
# LDAPS_PPT1          5.395178
# LDAPS_PPT2          5.776835
# LDAPS_PPT3          6.458608
# LDAPS_PPT4          6.826930
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# Next_Tmax          -0.336871
# Next_Tmin          -0.406685
# Day                 0.000365
# Month              -0.198626
# dtype: float64

# %%
df.head(10)
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
# 5      6.0          31.9          23.5    52.437126    85.307251
# 6      7.0          31.4          24.4    56.287189    81.019760
# 7      8.0          32.1          23.6    52.326218    78.004539
# 8      9.0          31.4          22.0    55.338791    80.784607
# 9     10.0          31.6          20.5    56.651203    86.849632
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# ...

# %%
df.dtypes
# Out:
# station             float64
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# Day                   int32
# Month                 int32
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7752 non-null   float64
#  1   Present_Tmax      7752 non-null   float64
#  2   Present_Tmin      7752 non-null   float64
#  3   LDAPS_RHmin       7752 non-null   float64
#  4   LDAPS_RHmax       7752 non-null   float64
#  5   LDAPS_Tmax_lapse  7752 non-null   float64
#  6   LDAPS_Tmin_lapse  7752 non-null   float64
#  7   LDAPS_WS          7752 non-null   float64
#  8   LDAPS_LH          7752 non-null   float64
#  9   LDAPS_CC1         7752 non-null   float64
#  10  LDAPS_CC2         7752 non-null   float64
#  11  LDAPS_CC3         7752 non-null   float64
#  12  LDAPS_CC4         7752 non-null   float64
#  13  LDAPS_PPT1        7752 non-null   float64
#  14  LDAPS_PPT2        7752 non-null   float64
#  15  LDAPS_PPT3        7752 non-null   float64
# ...

# %%
#assigning x value 
x=df.drop(['Next_Tmax','Next_Tmin','Slope','lat','lon','station','DEM','Solar radiation'],axis=1)
x.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          28.7          21.4    58.255688    91.116364         28.074101
# 1          31.9          21.6    52.263397    90.604721         29.850689
# 2          31.6          23.3    48.690479    83.973587         30.091292
# 3          32.0          23.4    58.239788    96.483688         29.704629
# 4          31.4          21.9    56.174095    90.155128         29.113934
#
#    LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  \
# 0         23.006936  6.818887   69.451805   0.233947   0.203896   0.161697
# 1         24.035009  5.691890   51.937448   0.225508   0.251771   0.159444
# 2         24.565633  6.138224   20.573050   0.209344   0.257469   0.204091
# 3         23.326177  5.650050   65.727144   0.216372   0.226002   0.161157
# 4         23.486480  5.735004  107.965535   0.151407   0.249995   0.178892
#
# ...

# %%
x.shape
# Out:
# (7752, 18)

# %%
y1=df['Next_Tmax']
y1
# Out:
# 0       29.1
# 1       30.5
# 2       31.1
# 3       31.7
# 4       31.2
#         ...
# 7747    28.3
# 7748    28.6
# 7749    27.8
# 7750    17.4
# 7751    38.9
# Name: Next_Tmax, Length: 7752, dtype: float64

# %%
y2=df['Next_Tmin']
y2
# Out:
# 0       21.2
# 1       22.5
# 2       23.9
# 3       24.3
# 4       22.5
#         ...
# 7747    18.1
# 7748    18.8
# 7749    17.4
# 7750    11.3
# 7751    29.8
# Name: Next_Tmin, Length: 7752, dtype: float64

# %%
sns.distplot(df.LDAPS_RHmax)

# %%
for I in df.columns:
    sns.boxplot(df[I])

# %%
df.dropna(axis=1,how='all',inplace=True)

# %%
Max = df[['Present_Tmax','LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_WS','LDAPS_LH','LDAPS_CC1','LDAPS_CC2','LDAPS_CC3','LDAPS_CC4','LDAPS_PPT1','LDAPS_PPT4',
          'lat','lon','DEM','Slope','Solar radiation','Next_Tmax']]

# %%
Max.head()
# Out:
#    Present_Tmax  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_WS    LDAPS_LH  \
# 0          28.7    91.116364         28.074101  6.818887   69.451805
# 1          31.9    90.604721         29.850689  5.691890   51.937448
# 2          31.6    83.973587         30.091292  6.138224   20.573050
# 3          32.0    96.483688         29.704629  5.650050   65.727144
# 4          31.4    90.155128         29.113934  5.735004  107.965535
#
#    LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT4  \
# 0   0.233947   0.203896   0.161697   0.130928         0.0         0.0
# 1   0.225508   0.251771   0.159444   0.127727         0.0         0.0
# 2   0.209344   0.257469   0.204091   0.142125         0.0         0.0
# 3   0.216372   0.226002   0.161157   0.134249         0.0         0.0
# 4   0.151407   0.249995   0.178892   0.170021         0.0         0.0
#
#        lat      lon       DEM   Slope  Solar radiation  Next_Tmax
# ...

# %%
Max.tail()
# Out:
#       Present_Tmax  LDAPS_RHmax  LDAPS_Tmax_lapse   LDAPS_WS    LDAPS_LH  \
# 7747          23.3    78.869858         26.352081   6.148918   72.058294
# 7748          23.3    77.294975         27.010193   6.542819   47.241457
# 7749          23.2    77.243744         27.939516   7.289264    9.090034
# 7750          20.0    58.936283         17.624954   2.882580  -13.603212
# 7751          37.6   100.000153         38.542255  21.857621  213.414006
#
#       LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT4  \
# 7747   0.030034   0.081035   0.000000   0.000000    0.000000    0.000000
# 7748   0.035874   0.074962   0.000000   0.000000    0.000000    0.000000
# 7749   0.048954   0.059869   0.000000   0.000796    0.000000    0.000000
# 7750   0.000000   0.000000   0.000000   0.000000    0.000000    0.000000
# 7751   0.967277   0.968353   0.983789   0.974710   23.701544   16.655469
#
#           lat      lon       DEM     Slope  Solar radiation  Next_Tmax
# ...

# %%
Max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Present_Tmax      7752 non-null   float64
#  1   LDAPS_RHmax       7752 non-null   float64
#  2   LDAPS_Tmax_lapse  7752 non-null   float64
#  3   LDAPS_WS          7752 non-null   float64
#  4   LDAPS_LH          7752 non-null   float64
#  5   LDAPS_CC1         7752 non-null   float64
#  6   LDAPS_CC2         7752 non-null   float64
#  7   LDAPS_CC3         7752 non-null   float64
#  8   LDAPS_CC4         7752 non-null   float64
#  9   LDAPS_PPT1        7752 non-null   float64
#  10  LDAPS_PPT4        7752 non-null   float64
#  11  lat               7752 non-null   float64
#  12  lon               7752 non-null   float64
#  13  DEM               7752 non-null   float64
#  14  Slope             7752 non-null   float64
#  15  Solar radiation   7752 non-null   float64
# ...

# %%
Max.describe()
# Out:
#        Present_Tmax  LDAPS_RHmax  LDAPS_Tmax_lapse     LDAPS_WS     LDAPS_LH  \
# count   7752.000000  7752.000000       7752.000000  7752.000000  7752.000000
# mean      29.782946    88.089988         29.497459     7.057092    61.768678
# std        2.960585     7.715499          3.158976     2.212072    34.383864
# min       20.000000    58.936283         17.624954     2.882580   -13.603212
# 25%       27.800000    84.038809         27.601014     5.647741    36.776474
# 50%       30.000000    89.699505         29.662273     6.531345    56.487289
# 75%       32.000000    93.704500         31.683819     8.007471    83.904586
# max       37.600000   100.000153         38.542255    21.857621   213.414006
#
#          LDAPS_CC1    LDAPS_CC2    LDAPS_CC3    LDAPS_CC4   LDAPS_PPT1  \
# count  7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean      0.365206     0.352635     0.315323     0.296297     0.586267
# ...

# %%
Feature = Max.drop(['Next_Tmax'],axis=1)
Feature.head(2)
# Out:
#    Present_Tmax  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_WS   LDAPS_LH  \
# 0          28.7    91.116364         28.074101  6.818887  69.451805
# 1          31.9    90.604721         29.850689  5.691890  51.937448
#
#    LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT4  \
# 0   0.233947   0.203896   0.161697   0.130928         0.0         0.0
# 1   0.225508   0.251771   0.159444   0.127727         0.0         0.0
#
#        lat      lon       DEM   Slope  Solar radiation
# 0  37.6046  126.991  212.3350  2.7850      5992.895996
# 1  37.6046  127.032   44.7624  0.5141      5869.312500

# %%
Feature.replace(np.NaN,0,inplace=True)

# %%
Target = Max['Next_Tmax']
Target.replace(np.NaN,0,inplace=True)
Target.isna().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(Feature,Target,test_size=0.1)
x_train.shape
# Out:
# (6976, 16)

# %%
y_train.shape
# Out:
# (6976,)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([ 3.28866794e-01, -2.25798731e-02,  3.95550872e-01, -2.20171042e-01,
#         8.28711743e-04, -8.32610909e-01, -2.66208932e-01, -1.50607364e+00,
#        -1.36821277e+00,  8.25957640e-02,  5.68261731e-02,  1.85825885e-01,
#        -1.80016035e+00, -5.01462808e-03,  2.07384816e-01,  4.77573504e-04])

# %%
lm.intercept_
# Out:
# 232.6423829308636

# %%
Train_score = lm.score(x_train,y_train)
Train_score
# Out:
# 0.7086807943756812

# %%
predict = lm.predict(x_test)

# %%
Test_score = lm.score(x_test,predict)
Test_score # overfitting
# Out:
# 1.0

# %%
#After Scaling 
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
Scaled_Data = ss.fit_transform(Feature)
pd.DataFrame(Scaled_Data,columns=Feature.columns)
# Out:
#       Present_Tmax  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_WS  LDAPS_LH  \
# 0        -0.365812     0.392272         -0.450605 -0.107691  0.223466
# 1         0.715126     0.325954          0.111825 -0.617200 -0.285944
# 2         0.613788    -0.533558          0.187995 -0.415415 -1.198187
# 3         0.748905     1.087971          0.065586 -0.636115  0.115133
# 4         0.546229     0.267679         -0.121416 -0.597708  1.343649
# ...            ...          ...               ...       ...       ...
# 7747     -2.189893    -1.195091         -0.995759 -0.410580  0.299276
# 7748     -2.189893    -1.399224         -0.787415 -0.232500 -0.422528
# 7749     -2.223673    -1.405864         -0.493212  0.104963 -1.532173
# 7750     -3.304610    -3.778834         -3.758582 -1.887272 -2.192213
# 7751      2.640545     1.543767          2.863390  6.691231  4.410648
#
#       LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT4  \
# ...

# %%
lm_s = LinearRegression()

# %%
Sc_X_Train,Sc_X_Test,Sc_y_Train,Sc_y_Test = train_test_split(Scaled_Data,Target)
lm_s.fit(Sc_X_Train,Sc_y_Train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm_s.coef_
# Out:
# array([ 9.82673436e-01, -2.00086739e-01,  1.23727422e+00, -4.99864314e-01,
#         2.68812907e-02, -2.00185725e-01, -2.27072412e-02, -4.44292731e-01,
#        -3.41138473e-01,  1.67409953e-01,  1.14388262e-01,  2.11322098e-04,
#        -1.35072562e-01, -2.50728904e-01,  2.74323550e-01,  2.00780810e-01])

# %%
lm_s.intercept_
# Out:
# 30.28856790659354

# %%
S_train = lm_s.score(Sc_X_Train,Sc_y_Train)
S_train
# Out:
# 0.703389388782517

# %%
s_predication = lm_s.predict(Sc_X_Test)

# %%
S_test = lm_s.score(Sc_X_Test,s_predication)
S_test
# Out:
# 1.0

# %%
np.log(Feature)  # Negative Skew
# Out:
#       Present_Tmax  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_WS  LDAPS_LH  \
# 0         3.356897     4.512137          3.334847  1.919696  4.240633
# 1         3.462606     4.506506          3.396208  1.739042  3.950040
# 2         3.453157     4.430502          3.404236  1.814535  3.023982
# 3         3.465736     4.569374          3.391303  1.731664  4.185512
# 4         3.446808     4.501532          3.371217  1.746589  4.681812
# ...            ...          ...               ...       ...       ...
# 7747      3.148453     4.367799          3.271547  1.816276  4.277475
# 7748      3.148453     4.347629          3.296214  1.878368  3.855272
# 7749      3.144152     4.346966          3.330042  1.986403  2.207179
# 7750      2.995732     4.076457          2.869316  1.058686       NaN
# 7751      3.627004     4.605172          3.651755  3.084550  5.363234
#
#       LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT4  \
# ...

# %%
np.log1p(Feature)   #  Removing Negative Skew
# Out:
#       Present_Tmax  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_WS  LDAPS_LH  \
# 0         3.391147     4.523053          3.369848  2.056542  4.254929
# 1         3.493473     4.517483          3.429159  1.900896  3.969111
# 2         3.484312     4.442340          3.436928  1.965464  3.071445
# 3         3.496508     4.579685          3.424413  1.894624  4.200612
# 4         3.478158     4.512563          3.404988  1.907318  4.691032
# ...            ...          ...               ...       ...       ...
# 7747      3.190476     4.380399          3.308793  1.966961  4.291258
# 7748      3.190476     4.360483          3.332568  2.020596  3.876219
# 7749      3.186353     4.359829          3.365208  2.114961  2.311548
# 7750      3.044522     4.093282          2.924502  1.356500       NaN
# 7751      3.653252     4.615122          3.677370  3.129285  5.367909
#
#       LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT4  \
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score

# %%
from sklearn.ensemble import RandomForestRegressor
print("Model: Random Forest Regressor")
forest_reg = RandomForestRegressor()

tree_scores = cross_val_score(forest_reg, x_train, y_train, scoring="neg_mean_squared_error", cv=20)
tree_rmse_scores = np.sqrt(-tree_scores)

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Model: Random Forest Regressor
# Scores: [1.01657501 1.05843566 1.09229708 1.00247279 1.34194033 0.91870544
#  1.02674391 0.98935143 0.98906502 0.92487447 0.92308607 1.02816857
#  1.00950621 1.17732967 0.99719589 0.97703673 0.99712373 0.90775432
#  0.93883368 1.16505875]
# Mean: 1.0240777380434474
# Standard deviation: 0.10223195267043465

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_squared_error

# %%
LR=LinearRegression()
LA=Lasso()
RI=Ridge()
EN=ElasticNet()
KNR=KNeighborsRegressor()
DTR=DecisionTreeRegressor(random_state=97)
ABR=AdaBoostRegressor(random_state=97)
RFR=RandomForestRegressor(random_state=97)
GBR=GradientBoostingRegressor(random_state=97)
XGR=XGBRegressor(random_state=97)

# %%
models=[]
models.append(('LinearRegression',LR))
models.append(('Lasso',LA))
models.append(('Ridge',RI))
models.append(('ElasticNet',EN))
models.append(('DecisionTreeRegressor',DTR))
models.append(('KNeighborsRegressor',KNR))
models.append(('AdaBoostRegressor',ABR))
models.append(('RandomForestRegressor',RFR))
models.append(('GradientBoostingRegressor',GBR))
models.append(('XGBRegressor',XGR))

# %%
Model=[]
R2_score=[]
cvs=[]
MSE=[]

for name,model in models:
    print('*********************************',name,'*********************************')
    print('\n',model)
    Model.append(name)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    r2=r2_score(y_test,pre)
    print('R2_score = ',r2)
    R2_score.append(r2)
    mse=mean_squared_error(y_test,pre)
    print("Mean_Squared_Error =",mse)
    MSE.append(round(mse,3))
    score= cross_val_score(model,x_train,y_train,cv=10,scoring='r2').mean()
    print('Cross_Val_Score = ',score)
    cvs.append(score)
    print('\n')
# Out:
# ********************************* LinearRegression *********************************
#
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# R2_score =  0.6963934599795905
# Mean_Squared_Error = 2.988521236987942
# Cross_Val_Score =  0.7055779696850972
#
#
# ********************************* Lasso *********************************
#
#  Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# R2_score =  0.619797804827761
# Mean_Squared_Error = 3.742483065566663
# Cross_Val_Score =  0.6225378162267365
#
#
# ********************************* Ridge *********************************
#
#  Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)
# R2_score =  0.6964450180180424
# Mean_Squared_Error = 2.988013730486794
# ...

# %%
result = pd.DataFrame({'Model': Model, 'R2_score': R2_score ,'Mean_Squared_Error' :MSE,'Cross_val_score':cvs})
result
# Out:
#                        Model  R2_score  Mean_Squared_Error  Cross_val_score
# 0           LinearRegression  0.696393               2.989         0.705578
# 1                      Lasso  0.619798               3.742         0.622538
# 2                      Ridge  0.696445               2.988         0.705587
# 3                 ElasticNet  0.638875               3.555         0.642132
# 4      DecisionTreeRegressor  0.780175               2.164         0.761669
# 5        KNeighborsRegressor  0.400985               5.896         0.429634
# 6          AdaBoostRegressor  0.738444               2.575         0.744317
# 7      RandomForestRegressor  0.891833               1.065         0.888247
# 8  GradientBoostingRegressor  0.829030               1.683         0.828655
# 9               XGBRegressor  0.828565               1.688         0.830622

# %%
# usage of gridsearch for improving the score

from sklearn.model_selection import GridSearchCV
param_grid = [{'n_estimators': [50,100,200], 'max_features': [5,10,15,18],
               'bootstrap': [True,False], 'min_samples_leaf':[1,2], 
               'min_samples_split':[2,3]}]

forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error',verbose=1)

grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 480 out of 480 | elapsed: 106.9min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
# ...

# %%
print(" ----------------- GRID_SEARCH INFO -----------------\n ")

print(grid_search.best_params_)
print(grid_search.best_estimator_)
print("Best CV score:", np.sqrt(-grid_search.best_score_))

cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
#  ----------------- GRID_SEARCH INFO -----------------
#
# {'bootstrap': False, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}
# RandomForestRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features=5, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=3, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# Best CV score: 0.9398935923501263
# 1.0135585864924435 {'bootstrap': True, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 1.007541320598788 {'bootstrap': True, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# ...

# %%
from sklearn.metrics import mean_squared_error


final_model = grid_search.best_estimator_
# predictions
final_predictions = final_model.predict(x_test)
# calculate RMSE
final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 0.8917621800911111

# %%
# Computing R^2 performance metric for the regression model
from sklearn import metrics
print('R2_Score: ', metrics.r2_score(y_test,final_predictions))
# Out:
# R2_Score:  0.9192108803251959

# %% [markdown]
# #we can understand that Random Forest Regressor is the highest accurate model with 91.9 %

# %%
#save the model

from sklearn.externals import joblib

joblib.dump(forest_reg,'Model_temperature.pkl')
# Out:
# ['Model_temperature.pkl']
