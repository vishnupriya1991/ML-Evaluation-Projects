# %%
#import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#read the file
df=pd.read_csv('customer churn.csv')
df.head()
#printing the top rows of the dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
#to check the number of rows and columns
df.shape

#it tells us that there are 3333 rows and 21 columns
# Out:
# (3333, 21)

# %%
df.dtypes

#it tells us about the datatypes of the dataset
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %%
df.info()
#info function gives a concise summary of the dataframe; here it tells us about the non null values, its count, datatypes and the number of datatypes in the dataset; here there are 1 boolean valued column,8 float valued column, 8 integer column and 4 object/string column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
df.describe()
#describe function tells us about the statistical inferences regarding the dataset
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# #From the above statistical table we can understand: We can see that for each column we have the following functions
#
# count- Number of non-null observations here all the columns contain 3333 entries
# mean- Mean of Values here mean of each column is found ie, mean of account length column=101.064806 , area code is 437.182418, etc
# std- Standard Deviation of the Values here standard deviation for account length is 39.822106, area code is 42.371290 etc
# min- Minimum value here it shows the min value for account length is 1 , area code is 408 etc
# max- Maximum value it shows the max value for account length is 243, area code is 510.
# 25%, 50%, and 75% - IQR values it shows percentile values at 25%,50% and 75% ; for account length is 74,101,127 respectively.

# %%
#checking the correlation
df.corr()
#the data has shown that the correlation is weak.
# Out:
#                         account length  area code  number vmail messages  \
# account length                1.000000  -0.012463              -0.004628
# area code                    -0.012463   1.000000              -0.001994
# number vmail messages        -0.004628  -0.001994               1.000000
# total day minutes             0.006216  -0.008264               0.000778
# total day calls               0.038470  -0.009646              -0.009548
# total day charge              0.006214  -0.008264               0.000776
# total eve minutes            -0.006757   0.003580               0.017562
# total eve calls               0.019260  -0.011886              -0.005864
# total eve charge             -0.006745   0.003607               0.017578
# total night minutes          -0.008955  -0.005825               0.007681
# total night calls            -0.013176   0.016522               0.007123
# total night charge           -0.008960  -0.005845               0.007663
# ...

# %%
#lets check the null values if any

df.isnull().sum()
#there are no null values in the dataset
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
sns.heatmap(df.isnull())
#we can visualize the null values using heatmap; here it is clear that there are no null values

# %%
#lets drop the irrelevant column phone number 
df = df.drop(['phone number'],axis=1)
df.shape
# Out:
# (3333, 20)

# %%
y = df["churn"].value_counts()
#print (y)
sns.barplot(y.index, y.values)
#here we are plotting the number of values in churn columns ie, true or false; we can see that there are more number of false cases in the target column.

# %%
df.groupby(["area code", "churn"]).size().unstack().plot(kind='bar', stacked=True, figsize=(5,5)) 
#lets plot the area code and churn and analyze the data
#we can see that the area xode 415 has more false churns than 408 and 510

# %%
df.groupby(["state", "churn"]).size().unstack().plot(kind='bar', stacked=True, figsize=(30,10)) 

#let splot the state vs churn and see
#we can see that the churn is less(false churn=0 is more )

# %%
df.groupby(["international plan", "churn"]).size().unstack().plot(kind='bar', stacked=True, figsize=(5,5))

#lets plot international plan vs churn; there are more false churn in plan 0

# %%
df.groupby(["voice mail plan", "churn"]).size().unstack().plot(kind='bar', stacked=True, figsize=(5,5)) 
#lets plot voice mail plan vs churn using groupby; there are more false churns in plan 0 and plan 1 which is indicated by the blue portion.

# %%
#Label encoder

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

cate = [key for key in dict(df.dtypes) if dict(df.dtypes)[key] in ['bool', 'object']]

# %%
le = preprocessing.LabelEncoder()
for i in cate:
    le.fit(df[i])
    df[i] = le.transform(df[i])

# %%
corrmat = df.corr(method='pearson')
f, ax = plt.subplots(figsize=(8, 8))

# Draw the heatmap using seaborn to visualize correlation
sns.heatmap(corrmat, vmax=1., square=True)
plt.title("Important variables correlation map", fontsize=15)
plt.show()


#it shows that the correlation between the variables is not strong.

# %%
#splitting the x and y variable as input and target variable respectively
y = df['churn']
x= df.iloc[0:20]

# %%
x.head()
# Out:
#    state  account length  area code  international plan  voice mail plan  \
# 0     16             128        415                   0                1
# 1     35             107        415                   0                1
# 2     31             137        415                   0                0
# 3     35              84        408                   1                0
# 4     36              75        415                   1                0
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: churn, dtype: int64

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier,RadiusNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC,SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score,roc_auc_score

# %%
xtrain, xtest, ytrain, ytest = train_test_split(df, y, 
                                                  stratify=y, 
                                                  random_state=60, 
                                                  test_size=0.2, shuffle=True)

# %%
print(xtrain.shape, xvalid.shape, ytrain.shape, yvalid.shape)
# Out:
# (2666, 20) (334, 19) (2666,) (334,)

# %%
#Standardizing the input data to fit in the model
scaler = preprocessing.StandardScaler()
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[-8.55699653e-01,  6.75992537e-01, -5.31762033e-01,
#         -5.77350269e-01,  1.52752523e+00,  1.22497262e+00,
#          1.13964258e+00,  5.15500417e-01,  1.13993567e+00,
#         -1.63928620e-01,  1.57307563e-01, -1.63881322e-01,
#          1.03962317e+00, -8.32410313e-01,  1.03827232e+00,
#         -4.05636011e-02, -1.01257911e+00, -4.15168249e-02,
#         -4.56491742e-01, -3.33333333e-01],
#        [ 5.64238636e-01,  2.02953879e-02, -5.31762033e-01,
#         -5.77350269e-01,  1.52752523e+00,  1.29966607e+00,
#         -7.22136394e-01,  1.10078473e+00, -7.22479537e-01,
#         -1.87623134e-01,  3.67050981e-01, -1.87355817e-01,
#          1.24155238e+00, -6.40315625e-02,  1.24180978e+00,
#          1.38882044e+00, -1.01257911e+00,  1.39009783e+00,
#         -4.56491742e-01, -3.33333333e-01],
#        [ 2.65304259e-01,  9.57005600e-01, -5.31762033e-01,
#         -5.77350269e-01, -6.54653671e-01, -6.42363689e-01,
# ...

# %% [markdown]
# As we know that the churn column is the target variable and it is denoted in boolean form(0 or 1),so this is a case of Logistic Regression.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier,ExtraTreesClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
KNN=KNeighborsClassifier()
SV=SVC()
LR=LogisticRegression()
DT=DecisionTreeClassifier(random_state=26)
GNB=GaussianNB()
RFC=RandomForestClassifier(random_state=26)
GBC=GradientBoostingClassifier(random_state=26)
ABC=AdaBoostClassifier(random_state=26)
ETC=ExtraTreesClassifier(random_state=26)

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('DTC', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV

# %%
num_folds = 10
seed = 7
scoring = 'accuracy'

# %%
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=num_folds, random_state=seed)
    cv_results = cross_val_score(model, xtrain, ytrain, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.909981 (0.029890)
# LDA: 0.851466 (0.018817)
# KNN: 0.875854 (0.020513)
# DTC: 1.000000 (0.000000)
# NB: 1.000000 (0.000000)
# SVM: 0.855217 (0.023834)

# %%
#We can see that Logistic Regression gives the highest accuracy score= 90%.
#KNN gives a score of 87%
#SVm gives a score of 85.5%
#LDA gives a score of 85.1%

# %%
# checking ensembles
ensembles = []
# Boosting methods
ensembles.append(('AB', AdaBoostClassifier()))
ensembles.append(('GBM', GradientBoostingClassifier()))
# Bagging methods
ensembles.append(('RF', RandomForestClassifier()))
ensembles.append(('ET', ExtraTreesClassifier()))

# %%
results = []
names = []
for name, model in ensembles:
    kfold = KFold(n_splits=num_folds, random_state=seed)
    cv_results = cross_val_score(model, xtrain, ytrain, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# AB: 1.000000 (0.000000)
# GBM: 1.000000 (0.000000)
# RF: 1.000000 (0.000000)
# ET: 1.000000 (0.000000)

# %% [markdown]
# We can conclude that Logistic Regression is the best fit model as it gives an accuracy of 90.98%

# %%
from sklearn.externals import joblib

joblib.dump(LR,'Model_ChurnPrediction.pkl')
# Out:
# ['Model_ChurnPrediction.pkl']
